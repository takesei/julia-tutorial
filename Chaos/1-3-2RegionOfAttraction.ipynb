# %% [markdown]
# # 吸引領域の判定
#
# 沈点(sink)周囲の値の吸い込みを代数的に求める.
# また, 源点(source)の値吐き出しも確認する.
#
# c.f.
# ##### 判定方法
# > **fixpointをpと置く.**
# > - $|x-p| - |f(x)-p| > 0$ を満たす時, 吸い込み.
# > - 満たさないときは吐き出し.

# %%
using Plots
gr()

using ForwardDiff

# %%
# c.f. 源点近くの軌道の変化量と源点の微分係数の差

f(x) = 2x * (1-x)
x_0 = 0.01
x_1 = f(x_0) 
x_2 = f(x_1)

v = (x_2 / x_1)
th_v = ForwardDiff.derivative(f, 0)

println("theoricalValue:", th_v, " value:", v, " error rate:", round(100(v-th_v)/th_v, 5), "%")
# Out:
# theoricalValue:2 value:1.9604 error rate:-1.98%

# %%
function solve_roa(Domein, Range, vec) 
  d = []
  for i in vec
    push!(d, abs(Domein-i)-abs(Range-i))
  end
  d
end
# Out:
# solve_roa (generic function with 1 method)

# %%
h(x) = 2x * (1-x)
Domein = [x for x=-1:0.01:2]

Range_x = copy(Domein)
Range_hx = [h(x) for x in Domein]

Range = solve_roa(Domein, Range_hx, [0, 1/2])

plot(Domein, Range, lw=5, label=["source:0", "sink: 1/2"])
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip3600">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3600)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip3601">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3600)" points="
# 39.3701,368.504 592.126,368.504 592.126,7.87402 39.3701,7.87402
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip3602">
#     <rect x="39" y="7" width="554" height="362"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip3602)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.3701,363.094 39.3701,13.2835
#   "/>
# <polyline clip-path="url(#clip3602)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   131.496,363.094 131.496,13.2835
#   "/>
# <polyline clip-path="url(#clip3602)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   223.622,363.094 223.622,13.2835
#   "/>
# <polyline clip-path="url(#clip3602)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   315.748,363.094 315.748,13.2835
#   "/>
# <polyline clip-path="url(#clip3602)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   407.874,363.094 407.874,13.2835
#   "/>
# <polyline clip-path="url(#clip3602)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   500,363.094 500,13.2835
#   "/>
# <polyline clip-path="url(#clip3602)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   592.126,363.094 592.126,13.2835
#   "/>
# <polyline clip-path="url(#clip3602)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,368.504 583.835,368.504
#   "/>
# <polyline clip-path="url(#clip3602)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,278.346 583.835,278.346
#   "/>
# <polyline clip-path="url(#clip3602)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,188.189 583.835,188.189
#   "/>
# <polyline clip-path="url(#clip3602)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,98.0315 583.835,98.0315
#   "/>
# <polyline clip-path="url(#clip3602)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,7.87402 583.835,7.87402
#   "/>
# <polyline clip-path="url(#clip3600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,368.504 592.126,368.504
#   "/>
# <polyline clip-path="url(#clip3600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,368.504 39.3701,363.094
#   "/>
# <polyline clip-path="url(#clip3600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   131.496,368.504 131.496,363.094
#   "/>
# <polyline clip-path="url(#clip3600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   223.622,368.504 223.622,363.094
#   "/>
# <polyline clip-path="url(#clip3600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   315.748,368.504 315.748,363.094
#   "/>
# <polyline clip-path="url(#clip3600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   407.874,368.504 407.874,363.094
#   "/>
# <polyline clip-path="url(#clip3600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   500,368.504 500,363.094
#   "/>
# <polyline clip-path="url(#clip3600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   592.126,368.504 592.126,363.094
#   "/>
# <polyline clip-path="url(#clip3600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,368.504 39.3701,7.87402
#   "/>
# <polyline clip-path="url(#clip3600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,368.504 47.6614,368.504
#   "/>
# <polyline clip-path="url(#clip3600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,278.346 47.6614,278.346
#   "/>
# <polyline clip-path="url(#clip3600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,188.189 47.6614,188.189
#   "/>
# <polyline clip-path="url(#clip3600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,98.0315 47.6614,98.0315
#   "/>
# <polyline clip-path="url(#clip3600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,7.87402 47.6614,7.87402
#   "/>
# <g clip-path="url(#clip3600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 39.3701, 382.304)" x="39.3701" y="382.304">-1.0</text>
# </g>
# <g clip-path="url(#clip3600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 131.496, 382.304)" x="131.496" y="382.304">-0.5</text>
# </g>
# <g clip-path="url(#clip3600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 223.622, 382.304)" x="223.622" y="382.304">0.0</text>
# </g>
# <g clip-path="url(#clip3600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 315.748, 382.304)" x="315.748" y="382.304">0.5</text>
# </g>
# <g clip-path="url(#clip3600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 407.874, 382.304)" x="407.874" y="382.304">1.0</text>
# </g>
# <g clip-path="url(#clip3600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 500, 382.304)" x="500" y="382.304">1.5</text>
# </g>
# <g clip-path="url(#clip3600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 592.126, 382.304)" x="592.126" y="382.304">2.0</text>
# </g>
# <g clip-path="url(#clip3600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 373.004)" x="33.3701" y="373.004">-3</text>
# </g>
# <g clip-path="url(#clip3600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 282.846)" x="33.3701" y="282.846">-2</text>
# </g>
# <g clip-path="url(#clip3600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 192.689)" x="33.3701" y="192.689">-1</text>
# </g>
# <g clip-path="url(#clip3600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 102.531)" x="33.3701" y="102.531">0</text>
# </g>
# <g clip-path="url(#clip3600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 12.374)" x="33.3701" y="12.374">1</text>
# </g>
# <polyline clip-path="url(#clip36

# %%
g(x) = (3x-x^3) / 2

Domein = [x for x=-3:0.01:3]
x_Range = copy(Domein)
gx_Range = [g(x) for x in Domein]

Range = solve_roa(Domein, gx_Range, [1, -1, 0])

plot(Domein, Range, lw=5, label=["Sink:1", "Sink:-1", "Source:0"])
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip3700">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3700)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip3701">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3700)" points="
# 39.3701,368.504 592.126,368.504 592.126,7.87402 39.3701,7.87402
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip3702">
#     <rect x="39" y="7" width="554" height="362"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.3701,363.094 39.3701,13.2835
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   131.496,363.094 131.496,13.2835
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   223.622,363.094 223.622,13.2835
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   315.748,363.094 315.748,13.2835
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   407.874,363.094 407.874,13.2835
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   500,363.094 500,13.2835
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   592.126,363.094 592.126,13.2835
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,368.504 583.835,368.504
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,302.935 583.835,302.935
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,237.366 583.835,237.366
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,171.797 583.835,171.797
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,106.228 583.835,106.228
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   47.6614,40.6586 583.835,40.6586
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,368.504 592.126,368.504
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,368.504 39.3701,363.094
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   131.496,368.504 131.496,363.094
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   223.622,368.504 223.622,363.094
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   315.748,368.504 315.748,363.094
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   407.874,368.504 407.874,363.094
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   500,368.504 500,363.094
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   592.126,368.504 592.126,363.094
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,368.504 39.3701,7.87402
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,368.504 47.6614,368.504
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,302.935 47.6614,302.935
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,237.366 47.6614,237.366
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,171.797 47.6614,171.797
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,106.228 47.6614,106.228
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,40.6586 47.6614,40.6586
#   "/>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 39.3701, 382.304)" x="39.3701" y="382.304">-3</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 131.496, 382.304)" x="131.496" y="382.304">-2</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 223.622, 382.304)" x="223.622" y="382.304">-1</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 315.748, 382.304)" x="315.748" y="382.304">0</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 407.874, 382.304)" x="407.874" y="382.304">1</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 500, 382.304)" x="500" y="382.304">2</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 592.126, 382.304)" x="592.126" y="382.304">3</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 373.004)" x="33.3701" y="373.004">-8</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 307.435)" x="33.3701" y="307.435">-6</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 241.866)" x="33.3701" y="241.866">-4</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.
